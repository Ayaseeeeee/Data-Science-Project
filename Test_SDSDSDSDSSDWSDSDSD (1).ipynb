# %%
"""
author: Kilvoctu
date: 2023.
title: stable-diffusion-webui
version: This is the forked version by Jie Ma
type: source code
URL: Downloaded by Jie Ma July 11th,2023 from url:https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/API
"""

#get api
import json
import requests
import io
import base64
from PIL import Image, PngImagePlugin

url = "http://127.0.0.1:7860" # stable diffusion local URL 

option_payload = {
#     "sd_model_checkpoint": "anything-v5-PrtRE.safetensors [7f96a1a9ca]",
    "sd_model_checkpoint": "Anything-v4.5-pruned-mergedVae.safetensors [a504b5b137]",
    

    "CLIP_stop_at_last_layers": 2
}

response = requests.post(url=f'{url}/sdapi/v1/options', json=option_payload)

payload = {
#     "prompt": "(finely detailed beautiful eyes and detailed face,masterpiece sidelighting,masterpiece,best quality,detailed,high resolution illustration)\
#     ,(urban techwear, fantasy background, village,tree,woods),\
#     (1girl,whole body,bishoujo,lustrous skin,looking down,looking at viewer),\
#     (black hair,blue eyes,black short skirt,ribbon,button shirt:1.2)",
    "prompt": "(a black dog),(no humans),(animal focus),",
    
    "steps": 20,
    "denoising_strength": 0.5,
    "seed": -1,#种子，随机数
    "batch_size": 1, #每次张数
    "n_iter": 1, #生成批次
    "cfg_scale": 7,#迭代
    "width": 512,
    "height": 768,
    "negative_prompt": "(worst quality:1.6),(low quality:1.6), ng_deepnegative_v1_75t",
    "sampler_index": "DPM++ 2M Karras"
}

response = requests.post(url=f'{url}/sdapi/v1/txt2img', json=payload)

r = response.json()

for i in r['images']:
    image = Image.open(io.BytesIO(base64.b64decode(i.split(",",1)[0])))

    png_payload = {
        "image": "data:image/png;base64," + i
    }
    response2 = requests.post(url=f'{url}/sdapi/v1/png-info', json=png_payload)

    pnginfo = PngImagePlugin.PngInfo()
    pnginfo.add_text("parameters", response2.json().get("info"))
    image.save('test_img/output_dog.png', pnginfo=pnginfo)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 52
#      48 response = requests.post(url=f'{url}/sdapi/v1/txt2img', json=payload)
#      50 r = response.json()
# ---> 52 for i in r['images']:
#      53     image = Image.open(io.BytesIO(base64.b64decode(i.split(",",1)[0])))
#      55     png_payload = {
#      56         "image": "data:image/png;base64," + i
#      57     }
#
# KeyError: 'images'

# %%
r

# %%
import torch
from torchvision.models.segmentation import fcn_resnet101, FCN_ResNet101_Weights
from torchvision.io.image import read_image
from torchvision.utils import draw_segmentation_masks
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # mpimg For reading images

img_path = 'test_img/output_dog.png'#output png
    
# Load model
weights=FCN_ResNet101_Weights.DEFAULT
model = fcn_resnet101(weights=weights, progress=False)
model = model.eval()

# Load image
img = read_image(img_path)

# Run model
input_tform = weights.transforms(resize_size=None)
batch = torch.stack([input_tform(img)])
output = model(batch)['out']
sem_class_to_idx = {cls: idx for (idx, cls) in enumerate(weights.meta['categories'])}
normalized_mask = torch.nn.functional.softmax(output, dim=1)

# %%
sem_class_to_idx
# Out:
# {'__background__': 0,
#  'aeroplane': 1,
#  'bicycle': 2,
#  'bird': 3,
#  'boat': 4,
#  'bottle': 5,
#  'bus': 6,
#  'car': 7,
#  'cat': 8,
#  'chair': 9,
#  'cow': 10,
#  'diningtable': 11,
#  'dog': 12,
#  'horse': 13,
#  'motorbike': 14,
#  'person': 15,
#  'pottedplant': 16,
#  'sheep': 17,
#  'sofa': 18,
#  'train': 19,
#  'tvmonitor': 20}

# %%
# Show results
class_idx = 1
binary_masks = (normalized_mask.argmax(class_idx) == sem_class_to_idx['dog'])
img_masked = draw_segmentation_masks(img, masks=binary_masks, alpha=1)
plt.subplot(1, 2, 1)
plt.imshow(img_masked.permute(1, 2, 0).numpy())
plt.subplot(1, 2, 2)
img_ori = mpimg.imread(img_path)
plt.imshow(img_ori)
plt.show()

# %% [markdown]
# -------------------------------------------exact mask-----------------------------------------------

# %%
"""
author: Mason-McGough
date: 2023.
title: A simple script that removes people from photos using the stable-diffusion-webui API
version: This is the forked version by Jie Ma
type: source code
URL: Downloaded by Jie Ma August 1th,2023 from https://gist.github.com/Mason-McGough/9733aff5bc9d04faecfbb81074617315
"""

from torchvision import transforms
from torchvision.io.image import read_image

def img_encode64(img):
    buffered = io.BytesIO()
    img.save(buffered, format='PNG')
    return base64.b64encode(buffered.getvalue()).decode("utf-8")

# Extract mask
tensor_to_pil = transforms.ToPILImage()
mask = normalized_mask[0, sem_class_to_idx['dog']]
mask = mask > 0.5

# Convert images to base64
img = read_image(img_path)
img = img[:3] if img.shape[0] > 3 else img

img = tensor_to_pil(img.cpu())
img_b64 = img_encode64(img)
mask = tensor_to_pil(mask.to(torch.float32).cpu())
mask_b64 = img_encode64(mask)

# %%
mask_b64
# Out:
# '...'

# %% [markdown]
# ------------------------------------------------img2img-----------------------------------------------

# %%
img = read_image('test_img/dog_sample.png')
img = img[:3] if img.shape[0] > 3 else img

# %%
from torchvision import transforms

def img64(img):
    img_buffer = io.BytesIO()
    img.save(img_buffer, format='PNG')
    img64_decode = base64.b64encode(img_buffer.getvalue()).decode("utf-8")
    return img64_decode

tensor_to_pil = transforms.ToPILImage()
img = tensor_to_pil(img.cpu())
img_b64 = img64(img)

# %%
# colour = #"green","red","white","yellow","black","blue",
# colour = #"cat","dog"
colour_list = ["cat",]
for colour in colour_list:
    
    payload = {
        "init_images":[img_b64],
    #     "prompt":"(green hair:1.2,blue eyes,short skirt,ribbon,button shirt:1.2)",
    #     "prompt":"(red hair:1.2,blue eyes,short skirt,ribbon,button shirt:1.2)",
    #     "prompt":"(white hair:1.2,blue eyes,short skirt,ribbon,button shirt:1.2)",
    #     "prompt":"(yellow hair:1.2,blue eyes,short skirt,ribbon,button shirt:1.2)",
    #     "prompt":"(black hair:1.2,blue eyes,short skirt,ribbon,button shirt:1.2)",
    #     "prompt":"(blue hair:1.2,blue eyes,short skirt,ribbon,button shirt:1.2)",

#         "prompt":"("+f"{colour} hair,blue eyes,short skirt,ribbon,button shirt:1.2)",
        "prompt":"(a"+f"{colour}),(animal focus),",
        "mask":mask_b64,
        "steps": 20,
        "cfg_scale": 7,#iteration 
#         'denoising_strength':0.62,
        'inpainting_fill':1,
#         "sampler_index": "DPM++ 2M Karras",
        "batch_size": 1,#Number of images per session
        "width": 512,
        "height": 768,
        'mask_blur': 0,
        'inpaint_full_res': False
    }

    # request = generate_request(img_b64,prompt="(white hair,green eyes,short shirts,sailor suit:1.2)",mask=mask_b64,**extra_options)
    test_sample_num = 50
    for j in range(test_sample_num):
        response = requests.post(url=f'{url}/sdapi/v1/img2img',json=payload)

        r = response.json()

        for i in r['images']:
            image = Image.open(io.BytesIO(base64.b64decode(i.split(",",1)[0])))

            png_payload = {
                "image": "data:image/png;base64," + i
            }
            response2 = requests.post(url=f'{url}/sdapi/v1/png-info', json=png_payload)

            pnginfo = PngImagePlugin.PngInfo()
            pnginfo.add_text("parameters", response2.json().get("info"))
            image.save('baseline/test_cat_dog2'+f'{colour}/cat'+f'{j}.png', pnginfo=pnginfo)

# %%
colour
# Out:
# 'cat'

# %%
r
# Out:
# {'images': ['...'],
#  'parameters': {'init_images': None,
#   'resize_mode': 0,
#   'denoising_strength': 0.62,
#   'image_cfg_scale': None,
#   'mask': None,
#   'mask_blur': 0,
#   'mask_blur_x': 4,
#   'mask_blur_y': 4,
#   'inpainting_fill': 1,
#   'inpaint_full_res': False,
#   'inpaint_full_res_padding': 0,
#   'inpainting_mask_invert': 0,
#   'initial_noise_multiplier': None,
#   'prompt': '(adog :1.2),(animal focus),',
#   'styles': None,
#   'seed': -1,
#   'subseed': -1,
#   'subseed_strength': 0,
#   'seed_resize_from_h': -1,
#   'seed_resize_from_w': -1,
#   'sampler_name': None,
#   'batch_size': 1,
#   'n_iter': 1,
#   'steps': 20,
#   'cfg_scale': 7.0,
#   'width': 512,
#   'height': 768,
#   'restore_faces': False,
#   'tiling': False,
#   'do_not_save_samples': False,
#   'do_not_save_grid': False,
#   'negative_prompt': None,
#   'eta': None,
#   's_min_uncond': 0.0,
#   's_churn': 0.0,
#   's_tmax': None,
#   's_tmin': 0.0,
#   's_noise': 1.0,
#   'override_settings': None,
#   'override_settings_restore_afterwards': True,
#   'script_args': [],
#   'sampler_index': 'DPM++ 2M Karras',
#   'include_init_images': False,
#   'script_name': None,
#   'send_images': True,
#   'save_images': False,
#   'alwayson_scripts': {}},
#  'info': '{"prompt": "(adog :1.2),(animal focus),", "all_prompts": ["(adog :1.2),(animal focus),"], "negative_prompt": "", "all_negative_prompts": [""], "seed": 174653854, "all_seeds": [174653854], "subseed": 2941246891, "all_subseeds": [2941246891], "subseed_strength": 0, "width": 512, "height": 768, "sampler_name": "DPM++ 2M Karras", "cfg_scale": 7.0, "steps": 20, "batch_size": 1, "restore_faces": false, "face_restoration_model": null, "sd_model_hash": "7f96a1a9ca", "seed_resize_from_w": -1, "seed_resize_from_h": -1, "denoising_strength": 0.62, "extra_generation_params": {}, "index_of_first_image": 0, "infotexts": ["(adog :1.2),(animal focus),\\nSteps: 20, Sampler: DPM++ 2M Karras, CFG scale: 7.0, Seed: 174653854, Size: 512x768, Model hash: 7f96a1a9ca, Model: anything-v5-PrtRE, Seed resize from: -1x-1, Denoising strength: 0.62, Clip skip: 2, Version: v1.4.0"], "styles": [], "job_timestamp": "20230806193944", "clip_skip": 2, "is_using_inpainting_conditioning": false}'}

# %%
# Show results
for i in range(6):
    plt.subplot(2, 3, i+1)
    img_path = 'V4.5/test_hair_red2'+f'{colour}/person'+f'{i}.png'
    img_ori = mpimg.imread(img_path)
    plt.imshow(img_ori)
plt.show()

# %% [markdown]
# ----------------------------------- evaluation img ---------------------------------------- (Use tragger)

# %%
origial = ["black","black","black","black","black",
           "blue","blue","blue","blue","blue",
           "green","green","green","green","green",
           "red","red","red","red","red",
           "white","white","white","white","white",
           "yellow","yellow","yellow","yellow","yellow",
           "dog","cat",]

entity_ori = ["hair","hair","hair","hair","hair",
              "hair","hair","hair","hair","hair",
              "hair","hair","hair","hair","hair",
              "hair","hair","hair","hair","hair",
              "hair","hair","hair","hair","hair",
              "hair","hair","hair","hair","hair",
              "cat","dog",]

replace = ["green","red","white","yellow","blue",
           "green","red","white","yellow","black",
           "red","white","yellow","black","blue",
           "green","white","yellow","black","blue",
           "green","red","yellow","black","blue",
           "green","red","white","black","blue",
           "cat","dog",]

entity_rep = ["person","person","person","person","person",
              "person","person","person","person","person",
              "person","person","person","person","person",
              "person","person","person","person","person",
              "person","person","person","person","person",
              "person","person","person","person","person",
              "cat","dog",]

# %%
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_distances
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import numpy as np

# %%
#read original
count = 32
dis_max = []
dis_min = []
dis_mean = []
dis_std = []
version = ['V5','V4.5','baseline']

for v in range(3):
    for ct in range(32):
        f = open("test_img/"+f"{replace[ct]}_"+f"{entity_ori[ct]}_sample.txt")  
        lines = f.readlines()
        f.close()

        #read replecement entity
        query =[]
        for i in range(50):
            colour_url=f'{version[v]}/test_'+f'{entity_ori[ct]}_'+f'{origial[ct]}2'+f'{replace[ct]}/'+f'{entity_rep[ct]}'+f'{i}.txt'
            f = open(colour_url) 
            line = f.readlines()
            f.close()
            query.append(line)

        list1 = lines
        cosine_distances_list = []

        for i in range(50):
            list2 = query[i]
            # create tfidf vectorizer
            tfidf_vectorizer = TfidfVectorizer()

            # fit and transform
            tfidf_matrix_list1 = tfidf_vectorizer.fit_transform(list1)
            tfidf_matrix_list2 = tfidf_vectorizer.transform(list2)

            # compute distances
            distance = cosine_distances(tfidf_matrix_list1, tfidf_matrix_list2)
            cosine_distances_list.append(distance[0][0])

        #Emphasis on distance variations
        cosine_distances_list = [i*120 for i in cosine_distances_list]
        cosine_distances_list_process = [round(i,3) for i in cosine_distances_list]

        dis_max.append(round(max(cosine_distances_list),3))
        dis_min.append(round(min(cosine_distances_list),3))
        dis_mean.append(round(np.mean(cosine_distances_list),3))
        dis_std.append(round(np.std(cosine_distances_list),3))

        print("Cosine Distances:")
        print(cosine_distances_list_process)
        print()
        print("max:"+f'{dis_max[ct+v*32]}')
        print("min:"+f'{dis_min[ct+v*32]}')
        print("mean:"+f'{dis_mean[ct+v*32]}')
        print("Standard Deviation:"+f'{dis_std[ct+v*32]}')
# Out:
# Cosine Distances:
# [11.942, 12.328, 13.461, 11.661, 19.251, 14.016, 15.777, 15.145, 14.613, 11.837, 16.371, 20.342, 9.985, 11.837, 16.009, 16.594, 13.984, 9.777, 15.175, 13.184, 11.738, 8.427, 15.502, 12.311, 17.337, 14.985, 12.304, 12.322, 12.896, 17.549, 18.298, 14.417, 12.807, 8.746, 14.19, 13.118, 12.962, 13.377, 15.599, 15.054, 11.613, 14.001, 19.237, 14.632, 11.759, 22.955, 13.722, 12.304, 15.957, 12.398]
#
# max:27.289
# min:10.065
# mean:15.489
# Standard Deviation:3.272
# Cosine Distances:
# [26.667, 24.946, 26.531, 36.848, 33.397, 48.446, 26.531, 30.0, 23.563, 46.515, 23.005, 33.068, 40.627, 35.079, 24.946, 23.005, 42.452, 36.848, 20.453, 26.667, 38.667, 31.682, 38.35, 25.132, 40.528, 50.718, 31.374, 26.531, 36.862, 26.531, 28.348, 33.159, 35.067, 21.975, 44.385, 26.531, 31.682, 28.076, 38.667, 40.627, 25.132, 33.322, 16.077, 36.848, 31.374, 28.348, 44.385, 25.132, 48.586, 38.667]
#
# max:50.718
# min:16.077
# mean:32.647
# Standard Deviation:8.039
# Cosine Distances:
# [14.17, 18.876, 24.634, 30.557, 35.983, 19.336, 27.418, 24.249, 30.328, 9.245, 27.048, 24.781, 22.02, 27.048, 29.932, 24.249, 26.103, 24.594, 21.527, 22.02, 18.876, 14.17, 40.0, 14.17, 32.907, 19.336, 29.932, 26.103, 36.733, 18.876, 21.527, 24.781, 24.781, 21.884, 14.037, 18.876, 22.02, 27.048, 24.781, 9.245, 19.336, 21.527, 27.624, 19.336, 32.907, 36.52, 24.781, 36.733, 21.527, 14.17]
#
# max:40.0
# min:9.245
# mean:23.973
# Standard Deviation:6.946

# %%
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ["index", "Name","original", "type","replacement", "max distance",'min distance','mean','std']
print(table)
# Out:
# +-------+------+----------+------+-------------+--------------+--------------+------+-----+
# | index | Name | original | type | replacement | max distance | min distance | mean | std |
# +-------+------+----------+------+-------------+--------------+--------------+------+-----+
# +-------+------+----------+------+-------------+--------------+--------------+------+-----+

# %%
for i in range(3):
    for j in range(32):
        table.add_row([j+i*32,version[i],origial[j],entity_ori[j],replace[j],dis_max[j+i*32],dis_min[j+i*32],dis_mean[j+i*32],dis_std[j+i*32]])

# %%
print(table)
# Out:
# +-------+----------+----------+------+-------------+--------------+--------------+--------+-------+
# | index |   Name   | original | type | replacement | max distance | min distance |  mean  |  std  |
# +-------+----------+----------+------+-------------+--------------+--------------+--------+-------+
# |   0   |    V5    |  black   | hair |    green    |    22.955    |    8.427     | 14.116 | 2.832 |
# |   1   |    V5    |  black   | hair |     red     |    32.463    |    12.352    | 19.606 | 5.117 |
# |   2   |    V5    |  black   | hair |    white    |    28.468    |    7.646     | 17.015 |  4.83 |
# |   3   |    V5    |  black   | hair |    yellow   |    41.238    |    22.792    | 29.363 | 3.557 |
# |   4   |    V5    |  black   | hair |     blue    |    18.545    |    6.466     | 11.064 | 2.458 |
# |   5   |    V5    |   blue   | hair |    green    |    20.003    |    10.801    | 14.995 | 2.362 |
# |   6   |    V5    |   blue   | hair |     red     |    26.962    |    8.945     | 18.37  | 4.163 |
# |   7   |    V5    |   blue   | hair |    white    |     15.4     |     4.99     | 9.442  | 2.479 |
# |   8   |    V5    |   blue   | hair |    yellow   |    30.913    |    17.522    | 24.979 | 3.253 |
# |   9   |    V5    |   blue   | hair |    black    |    26.026    |    18.182    | 21.724 |  1.67 |
# |   10  |    V5    |  green   | hair |     red     |    32.672    |    12.546    | 18.933 |  3.6  |
# |   11  |    V5    |  green   | hair |    white    |    25.672    |    9.755     | 15.309 | 3.878 |
# |   12  |    V5    |  green   | hair |    yellow   |    37.852    |    20.889    | 28.517 | 3.316 |
# |   13  |    V5    |  green   | hair |    black    |    24.525    |    13.568    | 19.934 | 2.227 |
# |   14  |    V5    |  green   | hair |     blue    |    18.694    |    9.707     | 14.296 | 1.883 |
# |   15  |    V5    |   red    | hair |    green    |    22.916    |    12.173    | 17.983 | 2.659 |
# |   16  |    V5    |   red    | hair |    white    |    19.38     |    5.909     | 10.426 |  3.53 |
# |   17  |    V5    |   red    | hair |    yellow   |    31.396    |    13.661    | 22.805 | 3.118 |
# |   18  |    V5    |   red    | hair |    black    |    28.129    |    18.756    | 24.353 | 1.939 |
# |   19  |    V5    |   red    | hair |     blue    |    22.008    |    12.356    | 16.921 | 2.304 |
# |   20  |    V5    |  white   | hair |    green    |    24.795    |    12.425    | 18.542 | 2.586 |
# |   21  |    V5    |  white   | hair |     red     |    23.024    |    10.654    | 15.591 | 2.892 |
# |   22  |    V5    |  white   | hair |    yellow   |    30.483    |    21.28     | 24.712 | 1.789 |
# |   23  |    V5    |  white   | hair |    black    |    27.902    |    12.965    | 21.978 | 3.699 |
# |   24  |    V5    |  white   | hair |     blue    |    18.269    |    7.749     | 13.06  | 2.587 |
# |   25  |    V5    |  yellow  | hair |    green    |    26.39     |    12.985    | 19.016 | 2.898 |
# |   26  |    V5    |  yellow  | hair |     red     |    20.605    |    8.598     | 13.115 | 2.845 |
# |   27  |    V5    |  yellow  | hair |    white    |    11.506    |    6.109     |  7.93  |  1.14 |
# |   28  |    V5    |  yellow  | hair |    black    |    29.094    |    17.694    | 23.748 | 2.606 |
# |   29  |    V5    |  yellow  | hair |     blue    |    20.326    |    7.944     | 15.212 | 2.291 |
# |   30  |    V5    |   dog    | cat  |     cat     |    46.515    |    18.959    | 31.479 | 7.284 |
# |   31  |    V5    |   cat    | dog  |     dog     |    49.544    |    9.245     | 25.882 | 8.564 |
# |   32  |   V4.5   |  black   | hair |    green    |    21.793    |    9.227     | 13.651 | 2.416 |
# |   33  |   V4.5   |  black   | hair |     red     |    31.437    |    11.666    | 19.471 | 4.756 |
# |   34  |   V4.5   |  black   | hair |    white    |    30.373    |    8.811     | 16.274 | 4.213 |
# |   35  |   V4.5   |  black   | hair |    yellow   |    37.544    |    23.202    | 30.329 | 3.661 |
# |   36  |   V4.5   |  black   | hair |     blue    |     15.1     |    6.757     | 10.865 | 2.012 |
# |   37  |   V4.5   |   blue   | hair |    green    |    22.071    |    10.459    | 14.269 | 2.146 |
# |   38  |   V4.5   |   blue   | hair |     red     |    25.186    |    11.331    | 17.993 | 3.917 |
# |   39  |   V4.5   |   blue   | hair |    white    |    19.799    |    5.401     | 9.725  | 2.878 |
# |   40  |   V4.5   |   blue   | hair |    yellow   |    37.307    |    17.089    | 27.486 | 3.721 |
# |   41  |   V4.5   |   blue   | hair |    black    |    29.462    |    17.608    | 22.425 | 2.353 |
# |   42  |   V4.5   |  green   | hair |     red     |    31.958    |    10.839    | 21.398 | 4.817 |
# |   43  |   V4.5   |  green   | hair |    white    |    20.978    |    6.729     | 14.903 | 3.579 |
# |   44  |   V4.5   |  green   | hair |    yellow   |    36.613    |    23.374    | 29.468 | 2.889 |
# |   45  |   V4.5   |  green   | hair |    black    |    29.647    |    11.451    | 20.124 | 3.659 |
# |   46  |   V4.5   |  green   | hair |     blue    |    18.99     |    8.834     | 14.154 | 1.825 |
# |   47  |   V4.5   |   red    | hair |    green    |    26.652    |    11.857    | 19.236 | 3.014 |
# |   48  |   V4.5   |   red    | hair |    white    |    19.026    |    5.997     | 9.502  |  2.68 |
# |   49  |   V4.5   |   red    | hair |    yellow   |    36.535    |    17.812    | 24.192 | 4.317 |
# |   50  |   V4.5   |   red    | hair |    black    |    31.082    |    20.455    | 25.393 | 2.395 |
# |   51  |   V4.5   |   red    | hair |     blue    |    22.155    |    12.096    | 17.22  |  2.31 |
# |   52  |   V4.5   |  white   | hair |    green    |    25.148    |    13.989    | 19.042 | 2.474 |
# |   53  |   V4.5   |  white   | hair |     red     |    23.716    |    11.679    | 16.804 | 2.824 |
# |   54  |   V4.5   |  white   | hair |    yellow   |    31.456    |    19.381    | 25.425 | 2.344 |
# |   55  |   V4.5   |  white   | hair |    black    |    29.094    |    12.192    | 22.353 | 4.007 |
# |   56  |   V4.5   |  white   | hair |     blue    |    17.931    |    7.498     | 13.514 | 2.421 |
# |   57  |   V4.5   |  yellow  | hair |    green    |    27.479    |    12.039    | 18.944 | 3.135 |
# |   58  |   V4.5   |  yellow  | hair |     red     |    18.697    |    9.285     | 13.843 | 2.705 |
# |   59  |   V4.5   |  yellow  | hair |    white    |    15.197    |    6.109     | 8.243  | 1.985 |
# |   60  |   V4.5   |  yellow  | hair |    black    |    32.896    |    12.026    | 24.479 | 3.738 |
# |   61  |   V4.5   |  yellow  | hair |     blue    |    23.003    |    8.404     | 15.639 |  2.7  |
# |   62  |   V4.5   |   dog    | cat  |     cat     |    46.515    |    18.959    | 29.813 | 6.584 |
# |   63  |   V4.5   |   cat    | dog  |     dog     |     40.0     |    9.245     | 23.756 | 7.098 |
# |   64  | baseline |  black   | hair |    green    |    29.784    |    9.905     | 16.566 | 4.116 |
# |   65  | baseline |  black   | hair |     red     |    30.186    |    13.366    | 19.314 | 3.138 |
# |   66  | baseline |  black   | hair |    white    |    29.023    |     8.96     | 12.656 | 3.395 |
# |   67  | baseline |  black   | hair |    yellow   |    38.148    |    20.506    | 28.459 | 3.704 |
# |   68  | baseline |  black   | hair |     blue    |    18.545    |    6.726     | 12.126 | 2.085 |
# |   69  | baseline |   blue   | hair |    green    |    24.703    |    9.905     | 17.361 | 3.019 |
# |   70  | baseline |   blue   | hair |     red     |    27.379    |    11.702    | 17.365 | 3.432 |
# |   71  | baseline |   blue   | hair |    white    |    19.898    |    6.158     | 10.05  | 3.353 |
# |   72  | baseline |   blue   | hair |    yellow   |    47.543    |    19.259    | 28.058 | 5.046 |
# |   73  | baseline |   blue   | hair |    black    |    24.795    |    14.227    | 20.396 | 2.574 |
# |   74  | baseline |  green   | hair |     red     |    34.249    |    16.94     | 23.829 | 4.241 |
# |   75  | baseline |  green   | hair |    white    |    28.683    |    8.218     |  14.0  |  4.2  |
# |   76  | baseline |  green   | hair |    yellow   |    39.831    |    22.457    | 30.447 | 4.497 |
# |   77  | baseline |  green   | hair |    black    |    32.576    |    15.306    | 22.773 | 3.159 |
# |   78  | baseline |  green   | hair |     blue    |    30.271    |    8.561     | 14.324 | 3.114 |
# |   79  | baseline |   red    | hair |    green    |    31.518    |    13.05     | 21.835 | 4.619 |
# |   80  | baseline |   red    | hair |    white    |    21.297    |    4.966     | 10.558 | 4.005 |
# |   81  | baseline |   red    | hair |    yellow   |    43.974    |    20.506    | 29.02  | 4.717 |
# |   82  | baseline |   red    | hair |    black    |    32.928    |    18.849    | 25.174 | 2.786 |
# |   83  | baseline |   red    | hair |     blue    |    22.168    |    13.353    | 17.012 | 2.078 |
# |   84  | baseline |  white   | hair |    green    |    34.368    |    17.092    | 22.535 | 3.528 |
# |   85  | baseline |  white   | hair |     red     |    33.016    |    12.726    | 19.981 | 3.976 |
# |   86  | baseline |  white   | hair |    yellow   |    32.321    |    19.62     | 26.24  | 2.427 |
# |   87  | baseline |  white   | hair |    black    |    29.091    |    14.297    | 24.431 | 3.374 |
# |   88  | baseline |  white   | hair |     blue    |    18.856    |    7.634     | 14.532 | 1.977 |
# |   89  | baseline |  yellow  | hair |    green    |    28.228    |    14.672    | 20.265 | 3.477 |
# |   90  | baseline |  yellow  | hair |     red     |    27.784    |    11.53     | 18.005 | 3.717 |
# |   91  | baseline |  yellow  | hair |    white    |    16.95     |    6.632     | 11.206 | 2.531 |
# |   92  | baseline |  yellow  | hair |    black    |    33.083    |    18.68     | 24.459 | 3.232 |
# |   93  | baseline |  yellow  | hair |     blue    |    27.289    |    10.065    | 15.489 | 3.272 |
# |   94  | baseline |   dog    | cat  |     cat     |    50.718    |    16.077    | 32.647 | 8.039 |
# |   95  | baseline |   cat    | dog  |     dog     |     40.0     |    9.245     | 23.973 | 6.946 |
# +-------+----------+----------+------+-------------+--------------+--------------+--------+-------+

# %%
#Evaluation modeling capacity 
v5 = 0
v4_5 = 0 
baseliene = 0

for i in range(len(dis_mean)):
    if i < 32:
        v5 = v5 + dis_mean[i]
    elif 31<i<64:
        v4_5 = v4_5 + dis_mean[i]
    elif 63<i<96:
        baseliene = baseliene + dis_mean[i]
        
print(v5)
print(v4_5)
print(baseliene)
# Out:
# 600.416
# 609.9330000000001
# 645.086

# %%
#Evaluating model stability
v5 = 0
v4_5 = 0 
baseliene = 0

for i in range(len(dis_std)):
    if i < 32:
        v5 = v5 + dis_std[i]
    elif 31<i<64:
        v4_5 = v4_5 + dis_std[i]
    elif 63<i<96:
        baseliene = baseliene + dis_std[i]
        
print(v5)
print(v4_5)
print(baseliene)
# Out:
# 102.356
# 105.57300000000002
# 117.77400000000003
